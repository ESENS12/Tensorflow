# %%
#한국어 음식 이름 추출
import requests
from bs4 import BeautifulSoup
 
url = 'https://ko.wiktionary.org/w/index.php?title=분류:한국어_음식'
res = requests.get(url)
html = res.text
bs = BeautifulSoup(html,'html.parser')
 
wordlist = bs.find_all('a','external text')
wordlist2 = []
 
for i in wordlist:
    word = i.get_text()
    wordlist2.append(word)
 
for i in wordlist2:
    sUrl = 'https://ko.wiktionary.org/w/index.php?title=분류:한국어_음식&from='+i
    res = requests.get(sUrl)
    html = res.text
    bs = BeautifulSoup(html,'html.parser')
    print(i+ " 파싱완료")
    result = bs.find('div',{'id':'mw-pages'}).find('ul')
    result = result.find_all('a')
    
    for j in result:
        word = j.get_text()
        with open('result.txt','a') as f:
            f.write(word+'\n')
            
    print(i+ " 기록완료")
# Out:
# 가 파싱완료
# 가 기록완료
# 거 파싱완료
# 거 기록완료
# 고 파싱완료
# 고 기록완료
# 구 파싱완료
# 구 기록완료
# 그 파싱완료
# 그 기록완료
# 기 파싱완료
# 기 기록완료
# 까 파싱완료
# 까 기록완료
# 나 파싱완료
# 나 기록완료
# 너 파싱완료
# 너 기록완료
# 노 파싱완료
# 노 기록완료
# 누 파싱완료
# 누 기록완료
# 느 파싱완료
# 느 기록완료
# 니 파싱완료
# 니 기록완료
# 다 파싱완료
# 다 기록완료
# 더 파싱완료
# 더 기록완료
# 도 파싱완료
# 도 기록완료
# 두 파싱완료
# 두 기록완료
# 드 파싱완료
# 드 기록완료
# 디 파싱완료
# 디 기록완료
# 따 파싱완료
# 따 기록완료
# 라 파싱완료
# 라 기록완료
# 러 파싱완료
# 러 기록완료
# 로 파싱완료
# 로 기록완료
# 루 파싱완료
# 루 기록완료
# 르 파싱완료
# 르 기록완료
# 리 파싱완료
# 리 기록완료
# 마 파싱완료
# 마 기록완료
# 머 파싱완료
# 머 기록완료
# 모 파싱완료
# 모 기록완료
# 무 파싱완료
# 무 기록완료
# 므 파싱완료
# 므 기록완료
# 미 파싱완료
# 미 기록완료
# 바 파싱완료
# 바 기록완료
# 버 파싱완료
# 버 기록완료
# 보 파싱완료
# 보 기록완료
# 부 파싱완료
# 부 기록완료
# 브 파싱완료
# 브 기록완료
# 비 파싱완료
# 비 기록완료
# 빠 파싱완료
# 빠 기록완료
# 사 파싱완료
# 사 기록완료
# 서 파싱완료
# 서 기록완료
# 소 파싱완료
# 소 기록완료
# 수 파싱완료
# 수 기록완료
# 스 파싱완료
# 스 기록완료
# 시 파싱완료
# 시 기록완료
# 싸 파싱완료
# 싸 기록완료
# 아 파싱완료
# 아 기록완료
# 어 파싱완료
# 어 기록완료
# 오 파싱완료
# 오 기록완료
# 우 파싱완료
# 우 기록완료
# 으 파싱완료
# 으 기록완료
# 이 파싱완료
# 이 기록완료
# 자 파싱완료
# 자 기록완료
# 저 파싱완료
# 저 기록완료
# 조 파싱완료
# 조 기록완료
# 주 파싱완료
# 주 기록완료
# 즈 파싱완료
# 즈 기록완료
# 지 파싱완료
# 지 기록완료
# 짜 파싱완료
# 짜 기록완료
# 차 파싱완료
# 차 기록완료
# 처 파싱완료
# 처 기록완료
# 초 파싱완료
# 초 기록완료
# 추 파싱완료
# 추 기록완료
# 츠 파싱완료
# 츠 기록완료
# 치 파싱완료
# 치 기록완료
# 카 파싱완료
# 카 기록완료
# 커 파싱완료
# 커 기록완료
# 코 파싱완료
# 코 기록완료
# 쿠 파싱완료
# 쿠 기록완료
# 크 파싱완료
# 크 기록완료
# 키 파싱완료
# 키 기록완료
# 타 파싱완료
# 타 기록완료
# 터 파싱완료
# 터 기록완료
# 토 파싱완료
# 토 기록완료
# 투 파싱완료
# 투 기록완료
# 트 파싱완료
# 트 기록완료
# 티 파싱완료
# 티 기록완료
# 파 파싱완료
# 파 기록완료
# 퍼 파싱완료
# 퍼 기록완료
# 포 파싱완료
# 포 기록완료
# 푸 파싱완료
# 푸 기록완료
# 프 파싱완료
# 프 기록완료
# 피 파싱완료
# 피 기록완료
# 하 파싱완료
# 하 기록완료
# 허 파싱완료
# 허 기록완료
# 호 파싱완료
# 호 기록완료
# 후 파싱완료
# 후 기록완료
# 흐 파싱완료
# 흐 기록완료
# 히 파싱완료
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-87d6bc753003> in <module>()
#      21     bs = BeautifulSoup(html,'html.parser')
#      22     print(i+ " 파싱완료")
# ---> 23     result = bs.find('div',{'id':'mw-pages'}).find('ul')
#      24     result = result.find_all('a')
#      25
#
# AttributeError: 'NoneType' object has no attribute 'find'
