# %%
try:
    from PIL import Image
except ImportError:
    import Image
from IPython.display import Image as ImageDisplay
import os
import matplotlib.pyplot as plt

import pytesseract

# %%
dirPath = '/Users/esens/Python/SearchNBlogWithoutAds_Crawler/train/advertise/'
imgNum = '53.jpg'
pytesseract.pytesseract.tesseract_cmd = r'/usr/local/bin/tesseract'

print(pytesseract.image_to_string(Image.open(dirPath + imgNum),lang='kor'))
ImageDisplay(dirPath + imgNum)

# %%
list = os.listdir(dirPath)
last_index = len(list)
for i in list:

    if i.find('jpg') > 0 or i.find('jpeg') >0:
        print(i)
        print(pytesseract.image_to_string(Image.open(dirPath + i),lang='kor'))
        plt.figure()
        plt.imshow(Image.open(dirPath + i))
        plt.axis('off')
        plt.show()
        print('=================================')
# Out:
# 63.jpg
# ...
# 77.jpg
# ...
# 88.jpg
# 흉 딩압세에서씨계듬민들빡제깅긍밭아 주관덕므르 작성던
# ...
# 89.jpg
# 담업제계에서 쎄듬 민울 제깅
# ...
# 76.jpg
# 맙릇 앰먹 앰뾰맹 맹모맹앰 앰걀릴박앰 맹앰 맹앰뾰맹
# 뾰 박뾰맹 뾰맙맹 앰뾰 박뾰박 앰 맹릴뾰 앰맹 앰박맹앰맹릴
# ...
# 62.jpg
# ...
# 74.jpg
# 위포스 팀은 네파키료부 터소
# ...
# 60.jpg
# 엽체르부터 제계뜸과 소가킁의 원고료톨 받고 작셍한 또스팅인너다맹
# ...
# 48.jpg
# 엽체르부터 제계뜸과 소가킁의 원고료톨 받고 작셍한 또스팅인너다맹
# ...
# 26.jpeg
# 면 큼불 시미오깅깅 묘태 본 엽체역 멋컵퀀붐 견깍콤팝아 뷔클에 켁섬히였슴너미
# ...
# 49.jpg
# ...
# 61.jpg
# 가 앰맹맹껄뭇뾰 맹맹앰박 뭉앰앰앰뾰룸츠
#
# 케 믓즈틱듬 빼클 땐톡믓 뻐뻔 빼뼈 습쌔 숯빼바티
# ...
# 75.jpg
# 빔아 식섣켠릴였슴너미 슥
# ...
# 59.jpg
# 굉잔 몹스몹림븐 앰욤몹츠부갤 겅맛옴 올 앰붜았펏 싣케 링먼 수 쌔링깍 슬식코깍 쎄앰걀말
# ...
# 71.jpg
# 미계 읍믄 뷰타의더밍몰 툼예 븐 엽게에서
# 개돔 또는 서 비스쿨 재칩받아 슬직아게 직심타였숱냐다
#
# 컨
# ...
# 65.jpg
# 어 큼붙 본 업치티 아욘퀀미 가굉쿰빌아 칙섬쾌슴너데
# ...
# 64.jpg
# 미 글븐 얍알약사계엽단울 봅테서 세염권불 세긍 빕아 솔직하게 직성된 묘팀밉너데맹
# ...
# 70.jpg
# 킴 많계팝 맹밥임맹므흉댑 맹계계 압고맹계 끄미계펏 배빡계무끄므 때미았슨배미맹
# ...
# 58.jpg
# 매따 주관멱므르 직성던 글압깅뭔디따
# ...
# 8.jpg
# 담써굉온미릴미꾕푸붐케 얍릴맹릴맙 맹너맙늪 자 균
# ...
# 66.jpg
# 홰홋
# 말 뾰말 목 릇맹공릴토 격써토굉였슴맙뭇깍맹
# ...
# 72.jpg
# 본 크쓰팀븐 랍디녹심제트부터 원곳료콜 지급 빌았미 면
#
#
#
# 멈시쿨너데
# ...
# 73.jpg
# 븐 므팅몬 디묘건자르부터 소집의 원고료믐 지완받아 작성하었슴너다
# ...
# 67.jpg
# 래덮입체르부떠 재쫄믈 제따곧람퍼작섬되있습너다
# ...
# 14.jpg
# ...
